# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://timesofindia.indiatimes.com/mostread.cms?day=1'

# %%
data = requests.get(url)

# %%
data.status_code
# Out:
# 200

# %%
data.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" ><html xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><meta charset="utf-8"><title>Most Viewed Recent News, Top News Stories - Times of India</title><meta name="description" content="Get all the most recently popular news stories with updates on Bollywood, Business, Sports, Politics and Live Update on latest news headlines at Times of India."><meta property="og:title" content="Most Viewed Recent News, Top News Stories - Times of India"><meta property="og:description" content="Get all the most recently popular news stories with updates on Bollywood, Business, Sports, Politics and Live Update on latest news headlines at Times of India."><meta content="https://timesofindia.indiatimes.com/mostread.cms" property="og:url"><link href="https://m.timesofindia.com/mostread.cms" medi
# ...

# %%
sup=(BeautifulSoup(data.text))

# %%
sup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd" >
# ...

# %%
sup.find('li')
# Out:
# <li><p>Lifetime</p><h3 data-userdetails="lifetime">0</h3></li>

# %%
sup.find('li').text
# Out:
# 'Lifetime0'

# %%
sup.find('h2')
# Out:
# <h2><i class="icon tp-sprite"></i>TOI TimesPoints</h2>

# %%
rows=sup.findAll('li')

# %%
rows
# Out:
# [<li><p>Lifetime</p><h3 data-userdetails="lifetime">0</h3></li>,
#  <li><p>Expired</p><h3 data-userdetails="expired">0</h3></li>,
#  <li><p>Redeemed</p><h3 data-userdetails="redeemed">0</h3></li>,
#  <li><a href="https://navbharattimes.indiatimes.com/" rel="nofollow" target="_blank">हिन्दी</a></li>,
#  <li><a href="https://maharashtratimes.indiatimes.com" rel="nofollow" target="_blank">मराठी</a></li>,
#  <li><a href="https://eisamay.indiatimes.com" rel="nofollow" target="_blank">বাংলা </a></li>,
#  <li><a href="https://www.iamgujarat.com/" rel="nofollow" target="_blank">ગુજરાતી</a></li>,
#  <li><a href="https://vijaykarnataka.indiatimes.com/" rel="nofollow" target="_blank">ಕನ್ನಡ</a></li>,
#  <li><a href="https://tamil.samayam.com" rel="nofollow" target="_blank">தமிழ்</a></li>,
#  <li><a href="https://telugu.samayam.com" rel="nofollow" target="_blank">తెలుగు</a></li>,
#  <li><a href="https://malayalam.samayam.com" rel="nofollow" target="_blank">മലയാളം</a></li>,
# ...

# %%
rows=sup.findAll('li',{'class':'clearfix'})

# %%
rows
# Out:
# [<li class="clearfix"><a class="w_img" href="/india/congress-crisis-peaks-as-capt-says-will-quit-party-sr-leaders-back-sibal/articleshow/86665878.cms" pg="#1" title="Congress crisis peaks as Capt says will quit party, senior leaders back Sibal"><img data-src="https://static.toiimg.com/thumb/imgsize-52104,msid-86665874,width-81,resizemode-4/86665874.jpg" pg="#1" src="/photo/34824568.cms"/></a><span class="desc"><a href="/india/congress-crisis-peaks-as-capt-says-will-quit-party-sr-leaders-back-sibal/articleshow/86665878.cms" pg="-2128958273#1" title="Congress crisis peaks as Capt says will quit party, senior leaders back Sibal">Congress crisis peaks as Capt says will quit party,</a></span></li>,
# ...

# %%
for news in rows:
    print(news.find('li'))
# Out:
# <li><a href="https://jsso.indiatimes.com/sso/identity/profile/edit?channel=toi" pg="#Click-Edit_Profile-1~Header-User_Profile" target="_blank">Edit Profile</a></li>
# <li><a class="active latestwidget" id="mostshared" pg="Most_Popular_RHS#Tab-Change-Most_Shared" style="cursor:pointer;">SHARED</a></li>
# ...

# %%
for news in rows:
    print(news.find(''))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>
# <div class="cbl"></div>

# %%
for news in rows:
    print(news.find('h1').text)
