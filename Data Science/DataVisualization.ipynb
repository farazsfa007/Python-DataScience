# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\ASUS\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
 import pandas as pd

# %%
df = pd.read_csv('Clean_Data.csv',index_col=0)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.to_csv('Clean_Data.csv')

# %%
df['1980'].plot()
# Out:
# <AxesSubplot:>

# %%
df['2013'].plot()
# Out:
# <AxesSubplot:>

# %%
df.set_index('OdName',inplace=True)

# %%
df.loc['India']
# Out:
# Type                Immigrants
# Coverage            Foreigners
# AREA                       935
# AreaName                  Asia
# REG                       5501
# RegName          Southern Asia
# DEV                        902
# DevName     Developing regions
# 1980                      8880
# 1981                      8670
# 1982                      8147
# 1983                      7338
# 1984                      5704
# 1985                      4211
# 1986                      7150
# 1987                     10189
# 1988                     11522
# 1989                     10343
# 1990                     12041
# 1991                     13734
# 1992                     13673
# 1993                     21496
# 1994                     18620
# 1995                     18489
# 1996                     23859
# 1997                     22268
# 1998                     17241
# 1999                     18974
# 2000                     28572
# 2001                     31223
# ...

# %%
df
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# OdName                                                                   ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
Years=[str(i) for i in range(1980,2014)]

# %%
df.loc['India',Years]
# Out:
# 1980     8880
# 1981     8670
# 1982     8147
# 1983     7338
# 1984     5704
# 1985     4211
# 1986     7150
# 1987    10189
# 1988    11522
# 1989    10343
# 1990    12041
# 1991    13734
# 1992    13673
# 1993    21496
# 1994    18620
# 1995    18489
# 1996    23859
# 1997    22268
# 1998    17241
# 1999    18974
# 2000    28572
# 2001    31223
# 2002    31889
# 2003    27155
# 2004    28235
# 2005    36210
# 2006    33848
# 2007    28742
# 2008    28261
# 2009    29456
# 2010    34235
# 2011    27509
# 2012    30933
# 2013    33087
# Name: India, dtype: object

# %%
df.loc['India',Years].plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[['India','China'],Years]
# Out:
#         1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# OdName                                                                 ...
# India   8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
# China   5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
#
#          2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# OdName
# India   28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China   36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 34 columns]

# %%
df.loc[['India','China'],Years].plot()
# Out:
# <AxesSubplot:xlabel='OdName'>

# %%
df.loc[['India','China'],Years].T.plot()
# Out:
# <AxesSubplot:>

# %%
df.loc[['India','Philippines','Viet Nam','China'],Years].T.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
df.loc[['India','Philippines','Viet Nam','China'],Years].T.plot( figsize=(20,7) )
# Out:
# <AxesSubplot:>

# %%
df.loc[['India','Philippines','Viet Nam','China'],Years].T.plot( figsize=(20,7) )
plt.title('Immegration Timeline Of Asian Country',size=20)
plt.xlabel('Years',size=15)
plt.ylabel('No. of Immegrants',size=15)
plt.xticks(rotation=40)
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30., 35.]),
#  [Text(-5.0, 0, '2009'),
#   Text(0.0, 0, '1980'),
#   Text(5.0, 0, '1985'),
#   Text(10.0, 0, '1990'),
#   Text(15.0, 0, '1995'),
#   Text(20.0, 0, '2000'),
#   Text(25.0, 0, '2005'),
#   Text(30.0, 0, '2010'),
#   Text(35.0, 0, '')])

# %% [markdown]
# ## BAR CHART

# %%
top_5_europe=df[df['AreaName']=='Europe'].sort_values('1990',ascending=False)['1990'].head()

# %%
top_5_europe.plot(kind='bar',figsize=(20,8))
plt.title('Top 5 Contries Of Europe',size=20)
plt.xlabel('Country name',size=15)
plt.ylabel('Immegration',size=15)
plt.xticks(rotation=360)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'United Kingdom of Great Britain and Northern Ireland'),
#   Text(1, 0, 'Poland'),
#   Text(2, 0, 'Portugal'),
#   Text(3, 0, 'Romania'),
#   Text(4, 0, 'France')])

# %%
df['Total']=df.sum(axis=1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_9076/2407737632.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total']=df.sum(axis=1)

# %%
df
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# OdName                                                                   ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
continent_data=df.groupby('AreaName').sum()['Total']

# %%
continent_data.plot(kind='pie',autopct='%1.2f%%',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Total'>

# %%
continent_data.plot(kind='pie',autopct='%1.2f%%',figsize=(20,10),labels=None)
plt.legend(continent_data.index)

# %%
continent_data.plot(kind='pie',autopct='%1.2f%%',figsize=(20,10),labels=None,)
plt.legend(continent_data.index)
